# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "plotly_mimetype"

def show_chart(filename):
    path = 'csv/' + filename + '.csv'
    df = pd.read_csv(path)
#     print(len(df))
#     df = df.head(300)
#     df = df.tail(250)
    fig = px.line(df, x = "RX Date/Time", y = df.columns, title=filename)

    fig.update_xaxes(showticklabels = False)
    fig.show()
    print('datapoints recorded:',len(df))
#     display(df.max())
#     display(df.min())
    print('------------------------------------------------------------------------------------------------------------')

# %%
# show_chart('sanitiser')
# show_chart('10g_semi-fresh_coffee')
# show_chart('10g_fresh_cheap')
# show_chart('less_coffee')
# show_chart('03_25_17-58_old_ground_2_pumps')
show_chart('5min_fresh_shit')
show_chart('5min_5g_fresh_el_salvador')
# Out:
# datapoints recorded: 602
# ------------------------------------------------------------------------------------------------------------
# datapoints recorded: 600
# ------------------------------------------------------------------------------------------------------------

# %%
path = 'csv/10g_fresh_cheap.csv'
path = 'csv/10g_semi-fresh_coffee.csv'
df = pd.read_csv(path)
df = df
# Out:
#                    RX Date/Time  MQ2(field 1)  MQ3(field 2)  MQ4(field 3)  \
# 0     2022/03/18/ 16:57:37::445          1.94          1.35          1.41
# 1     2022/03/18/ 16:57:37::446          1.94          1.35          1.41
# 2     2022/03/18/ 16:57:37::446          1.94          1.35          1.41
# 3     2022/03/18/ 16:57:37::446          1.94          1.35          1.41
# 4     2022/03/18/ 16:57:38::516          1.94          1.35          1.41
# ...                         ...           ...           ...           ...
# 2997  2022/03/18/ 17:22:47::244          1.72          1.12          1.23
# 2998  2022/03/18/ 17:22:48::285          1.72          1.11          1.23
# 2999  2022/03/18/ 17:22:48::285          1.72          1.11          1.23
# 3000  2022/03/18/ 17:22:49::332          1.72          1.12          1.23
# 3001  2022/03/18/ 17:22:49::333          1.72          1.11          1.23
#
#       MQ6(field 4)  MQ7(field 5)  MQ8(field 6)  MQ9(field 7)  MQ135(field 8)
# ...
